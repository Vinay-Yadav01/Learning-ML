# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinay-Yadav01/Learning-ML/blob/main/P11(Titanic_Ship_Survival_using_Decision_Tree).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df = df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'], axis='columns')
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
# prompt: Find na value for each column

for column in df.columns:
  print(f"Column '{column}' has {df[column].isna().sum()} NA values")
# Out:
# Column 'Survived' has 0 NA values
# Column 'Pclass' has 0 NA values
# Column 'Sex' has 0 NA values
# Column 'Age' has 177 NA values
# Column 'Fare' has 0 NA values

# %%
# prompt: Fill na of age

df.Age = df.Age.fillna(df.Age.mean())
for column in df.columns:
  print(f"Column '{column}' has {df[column].isna().sum()} NA values")
# Out:
# Column 'Survived' has 0 NA values
# Column 'Pclass' has 0 NA values
# Column 'Sex' has 0 NA values
# Column 'Age' has 0 NA values
# Column 'Fare' has 0 NA values

# %%
le = LabelEncoder()
df['Sex'] = le.fit_transform(df['Sex'])
df.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    1  22.0   7.2500
# 1         1       1    0  38.0  71.2833
# 2         1       3    0  26.0   7.9250
# 3         1       1    0  35.0  53.1000
# 4         0       3    1  35.0   8.0500

# %%
X = df.drop('Survived', axis='columns')
y = df['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      Pclass  Sex        Age     Fare
# 687       3    1  19.000000  10.1708
# 288       2    1  42.000000  13.0000
# 600       2    0  24.000000  27.0000
# 821       3    1  27.000000   8.6625
# 158       3    1  29.699118   8.6625
# ..      ...  ...        ...      ...
# 262       1    1  52.000000  79.6500
# 626       2    1  57.000000  12.3500
# 81        3    1  29.000000   9.5000
# 329       1    0  16.000000  57.9792
# 682       3    1  20.000000   9.2250
#
# [712 rows x 4 columns]

# %%
X_test
# Out:
#      Pclass  Sex        Age      Fare
# 407       2    1   3.000000   18.7500
# 342       2    1  28.000000   13.0000
# 659       1    1  58.000000  113.2750
# 77        3    1  29.699118    8.0500
# 466       2    1  29.699118    0.0000
# ..      ...  ...        ...       ...
# 67        3    1  19.000000    8.1583
# 112       3    1  22.000000    8.0500
# 310       1    0  24.000000   83.1583
# 316       2    0  24.000000   26.0000
# 62        1    1  45.000000   83.4750
#
# [179 rows x 4 columns]

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[3,0,19,8.1583]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.score(X_test, y_test)
# Out:
# 0.7653631284916201
