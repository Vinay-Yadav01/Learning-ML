# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinay-Yadav01/Learning-ML/blob/main/P6(Insurance_Prediction).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance_data.csv')
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df['age'], df['bought_insurance'])
plt.xlabel('Age')
plt.ylabel('Bought Insurance')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df['bought_insurance'], test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 1])

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#    age
# 9   61
# 2   47
# 5   56

# %%
model.predict_proba(X_test)
# Out:
# array([[0.06540786, 0.93459214],
#        [0.29046818, 0.70953182],
#        [0.11622997, 0.88377003]])
